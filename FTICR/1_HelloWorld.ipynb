# %%
import seaborn as sns
import pandas as pd
import matplotlib as mpl

# %%
df = pd.read_csv('data/MONetShinyData_forPY.csv')

# %%
df.head()
# Out:
#     Sample_ID Sample    ID  SiteName Location                  biome_name  \
# 0  1000S_ANZA  1000S  ANZA  ANZA_BTM      BTM  Deserts & Xeric Shrublands
# 1  1000S_FTA3  1000S  FTA3  FTA3_BTM      BTM  Deserts & Xeric Shrublands
# 2  1000S_FTA5  1000S  FTA5  FTA5_BTM      BTM  Deserts & Xeric Shrublands
# 3  1000S_JORN  1000S  JORN  JORN_BTM      BTM  Deserts & Xeric Shrublands
# 4  1000S_MOAB  1000S  MOAB  MOAB_BTM      BTM  Deserts & Xeric Shrublands
#
#     latitude   longitude  mean_GWC  K_mg_per_kg  ...  wet.bulk.density  \
# 0  33.305325 -116.254011     1.000         82.0  ...              2.07
# 1  46.921647 -120.658644       NaN        562.0  ...              1.79
# 2  46.904500 -120.624100     1.203        548.0  ...              2.06
# 3  32.590920 -106.842860     1.051          NaN  ...               NaN
# 4  38.247420 -109.388300     1.008          NaN  ...               NaN
#
#    pnm.abs.permeability_x  pnm.total.flow.rate_x  pnm.tortuosity_x  \
# ...

# %%
print('You did it!')
# Out:
# You did it!
