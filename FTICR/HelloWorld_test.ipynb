# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import scipy as sp

# %%
df = pd.read_csv('data/Longform_Formula_Level.csv')

# %%
df.head()
# Out:
#   Molecular.Formula  C   H  O  N  S  P El_comp    Class  Error_ppm  ...  \
# 0          C7 H6 O2  7   6  2  0  0  0     CHO   lignin  -0.026546  ...
# 1          C6 H8 O3  6   8  3  0  0  0     CHO   lignin  -0.051096  ...
# 2         C7 H12 O2  7  12  2  0  0  0     CHO    lipid  -0.047839  ...
# 3       C5 H7 O3 N1  5   7  3  1  0  0    CHON   lignin  -0.034964  ...
# 4         C6 H10 O3  6  10  3  0  0  0     CHO  protein  -0.012927  ...
#
#           MF      NOSC    GFE_cox       O/C       H/C    Sample Intensity  \
# 0   C7H6O2N0 -0.285714  68.442857  0.285714  0.857143  ANZA_BTM         1
# 1   C6H8O3N0 -0.333333  69.800000  0.500000  1.333333  ANZA_BTM         1
# 2  C7H12O2N0 -1.142857  92.871429  0.285714  1.714286  ANZA_BTM         1
# 3   C5H7O3N1  0.400000  48.900000  0.600000  1.400000  ANZA_BTM         1
# 4  C6H10O3N0 -0.666667  79.300000  0.500000  1.666667  ANZA_BTM         1
#
#    Site  Depth         BiomeType
# 0  ANZA    BTM  Desert_Shrubland
# 1  ANZA    BTM  Desert_Shrubland
# 2  ANZA    BTM  Desert_Shrubland
# 3  ANZA    BTM  Desert_Shrubland
# 4  ANZA    BTM  Desert_Shrubland
#
# [5 rows x 26 columns]

# %%
print('Congratulations, you are ready for the hands on session on Nov 8!')
# Out:
# Congratulations, you are ready for the hands on session on Nov 8!
